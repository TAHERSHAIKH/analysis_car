# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Cars.csv')
df.head()
# Out:
#    symboling  normalized-losses  make  fuel-type   aspiration num-of-doors  \
# 0        NaN                  0     3        122  alfa-romero          gas
# 1        NaN                  1     3        122  alfa-romero          gas
# 2        NaN                  2     1        122  alfa-romero          gas
# 3        NaN                  3     2        164         audi          gas
# 4        NaN                  4     2        164         audi          gas
#
#   body-style drive-wheels engine-location wheel-base  ...   bore  stroke  \
# 0        std          two     convertible        rwd  ...  130.0    mpfi
# 1        std          two     convertible        rwd  ...  130.0    mpfi
# 2        std          two       hatchback        rwd  ...  152.0    mpfi
# 3        std         four           sedan        fwd  ...  109.0    mpfi
# 4        std         four           sedan        4wd  ...  136.0    mpfi
#
#    compression-ratio  horsepower  peak-rpm  city-mpg highway-mpg price  \
# 0               3.47        2.68       9.0     111.0      5000.0  21.0
# 1               3.47        2.68       9.0     111.0      5000.0  21.0
# 2               2.68        3.47       9.0     154.0      5000.0  19.0
# 3               3.19        3.40      10.0     102.0      5500.0  24.0
# 4               3.19        3.40       8.0     115.0      5500.0  18.0
#
#    Unnamed: 26 Unnamed: 27
# 0         27.0     13495.0
# 1         27.0     16500.0
# 2         26.0     16500.0
# 3         30.0     13950.0
# 4         22.0     17450.0
#
# [5 rows x 28 columns]

# %%
#حذف الاعمدة الغير مهمة 

#Delete uncons task columns

df.drop('Unnamed: 26', axis=1 , inplace=True)
df.drop('Unnamed: 27', axis=1 , inplace=True)

# %%
df.head()
# Out:
#    symboling  normalized-losses  make  fuel-type   aspiration num-of-doors  \
# 0        NaN                  0     3        122  alfa-romero          gas
# 1        NaN                  1     3        122  alfa-romero          gas
# 2        NaN                  2     1        122  alfa-romero          gas
# 3        NaN                  3     2        164         audi          gas
# 4        NaN                  4     2        164         audi          gas
#
#   body-style drive-wheels engine-location wheel-base  ... engine-size  \
# 0        std          two     convertible        rwd  ...        dohc
# 1        std          two     convertible        rwd  ...        dohc
# 2        std          two       hatchback        rwd  ...        ohcv
# 3        std         four           sedan        fwd  ...         ohc
# 4        std         four           sedan        4wd  ...         ohc
#
#    fuel-system   bore  stroke  compression-ratio  horsepower peak-rpm  \
# 0         four  130.0    mpfi               3.47        2.68      9.0
# 1         four  130.0    mpfi               3.47        2.68      9.0
# 2          six  152.0    mpfi               2.68        3.47      9.0
# 3         four  109.0    mpfi               3.19        3.40     10.0
# 4         five  136.0    mpfi               3.19        3.40      8.0
#
#   city-mpg  highway-mpg price
# 0    111.0       5000.0  21.0
# 1    111.0       5000.0  21.0
# 2    154.0       5000.0  19.0
# 3    102.0       5500.0  24.0
# 4    115.0       5500.0  18.0
#
# [5 rows x 26 columns]

# %%
#معرفة حجم البيانات وعدد الاعمدة 

#Find out the size of the data and the number of columns 

df.shape
# Out:
# (201, 28)

# %%
#وصف البينات

#Data description 

df.describe()
# Out:
#        symboling  normalized-losses        make  fuel-type       width  \
# count        0.0         201.000000  201.000000  201.00000  200.000000
# mean         NaN         102.900498    0.840796  122.00000   98.745500
# std          NaN          59.234956    1.254802   31.99625    6.037353
# min          NaN           0.000000   -2.000000   65.00000   86.600000
# 25%          NaN          53.000000    0.000000  101.00000   94.500000
# 50%          NaN         103.000000    1.000000  122.00000   96.950000
# 75%          NaN         154.000000    2.000000  137.00000  102.400000
# max          NaN         204.000000    3.000000  256.00000  120.900000
#
#            height  curb-weight  engine-type  num-of-cylinders        bore  \
# count  200.000000    200.00000   200.000000        200.000000  200.000000
# mean   174.128000     65.87400    53.758000       2553.135000  126.805000
# std     12.309453      2.09585     2.450871        517.345007   41.638996
# min    141.100000     60.30000    47.800000       1488.000000   61.000000
# 25%    166.675000     64.10000    52.000000       2163.000000   97.750000
# 50%    173.200000     65.50000    54.100000       2414.000000  119.500000
# 75%    183.200000     66.52500    55.525000       2922.250000  142.000000
# max    208.100000     72.00000    59.800000       4066.000000  326.000000
#
#        compression-ratio  horsepower    peak-rpm    city-mpg  highway-mpg  \
# count         200.000000  200.000000  200.000000  200.000000   200.000000
# mean            3.328464    3.257438   10.167600  103.343970  5116.175879
# std             0.266841    0.316750    4.014738   37.451788   478.892603
# min             2.540000    2.070000    7.000000   48.000000  4150.000000
# 25%             3.150000    3.110000    8.575000   70.000000  4800.000000
# 50%             3.310000    3.290000    9.000000   95.000000  5117.587940
# 75%             3.580000    3.410000    9.400000  116.000000  5500.000000
# max             3.940000    4.170000   23.000000  262.000000  6600.000000
#
#             price  Unnamed: 26  Unnamed: 27
# count  200.000000    200.00000    200.00000
# mean    25.210000     30.71500  13160.04000
# std      6.424349      6.82029   7938.84696
# min     13.000000     16.00000   5118.00000
# 25%     19.000000     25.00000   7775.00000
# 50%     24.000000     30.00000  10270.00000
# 75%     30.000000     34.00000  16500.00000
# max     49.000000     54.00000  45400.00000

# %%
#روئية البيانات بطريقة اوضح

#check data types

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          0 non-null      float64
#  1   normalized-losses  201 non-null    int64
#  2   make               201 non-null    int64
#  3   fuel-type          201 non-null    int64
#  4   aspiration         201 non-null    object
#  5   num-of-doors       201 non-null    object
#  6   body-style         201 non-null    object
#  7   drive-wheels       201 non-null    object
#  8   engine-location    200 non-null    object
#  9   wheel-base         200 non-null    object
#  10  length             200 non-null    object
#  11  width              200 non-null    float64
#  12  height             200 non-null    float64
#  13  curb-weight        200 non-null    float64
#  14  engine-type        200 non-null    float64
#  15  num-of-cylinders   200 non-null    float64
#  16  engine-size        200 non-null    object
#  17  fuel-system        200 non-null    object
#  18  bore               200 non-null    float64
#  19  stroke             200 non-null    object
#  20  compression-ratio  200 non-null    float64
#  21  horsepower         200 non-null    float64
#  22  peak-rpm           200 non-null    float64
#  23  city-mpg           200 non-null    float64
#  24  highway-mpg        200 non-null    float64
#  25  price              200 non-null    float64
#  26  Unnamed: 26        200 non-null    float64
#  27  Unnamed: 27        200 non-null    float64
# dtypes: float64(15), int64(3), object(10)
# memory usage: 44.1+ KB

# %%
#معرفة عدد البيانات

#Find out how many data

df.count()
# Out:
# symboling              0
# normalized-losses    201
# make                 201
# fuel-type            201
# aspiration           201
# num-of-doors         201
# body-style           201
# drive-wheels         201
# engine-location      200
# wheel-base           200
# length               200
# width                200
# height               200
# curb-weight          200
# engine-type          200
# num-of-cylinders     200
# engine-size          200
# fuel-system          200
# bore                 200
# stroke               200
# compression-ratio    200
# horsepower           200
# peak-rpm             200
# city-mpg             200
# highway-mpg          200
# price                200
# Unnamed: 26          200
# Unnamed: 27          200
# dtype: int64

# %%
#معرفة عدد اللاعمدة المتكررة او النوع

#Find out how many columns are repeated or type

df.duplicated().sum()
# Out:
# 0

# %%
#معرفة نوع القيم 

#Type of values

df.value_counts()
# Out:
# Series([], dtype: int64)

# %% [markdown]
# # Analysis phase

# %%
df.head()
# Out:
#    symboling  normalized-losses  make  fuel-type   aspiration num-of-doors  \
# 0        NaN                  0     3        122  alfa-romero          gas
# 1        NaN                  1     3        122  alfa-romero          gas
# 2        NaN                  2     1        122  alfa-romero          gas
# 3        NaN                  3     2        164         audi          gas
# 4        NaN                  4     2        164         audi          gas
#
#   body-style drive-wheels engine-location wheel-base  ...   bore  stroke  \
# 0        std          two     convertible        rwd  ...  130.0    mpfi
# 1        std          two     convertible        rwd  ...  130.0    mpfi
# 2        std          two       hatchback        rwd  ...  152.0    mpfi
# 3        std         four           sedan        fwd  ...  109.0    mpfi
# 4        std         four           sedan        4wd  ...  136.0    mpfi
#
#    compression-ratio  horsepower  peak-rpm  city-mpg highway-mpg price  \
# 0               3.47        2.68       9.0     111.0      5000.0  21.0
# 1               3.47        2.68       9.0     111.0      5000.0  21.0
# 2               2.68        3.47       9.0     154.0      5000.0  19.0
# 3               3.19        3.40      10.0     102.0      5500.0  24.0
# 4               3.19        3.40       8.0     115.0      5500.0  18.0
#
#    Unnamed: 26 Unnamed: 27
# 0         27.0     13495.0
# 1         27.0     16500.0
# 2         26.0     16500.0
# 3         30.0     13950.0
# 4         22.0     17450.0
#
# [5 rows x 28 columns]

# %%
#معرفة انوع السيارتا

#Knowing the types of cars

df['aspiration'].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mercury',
#        'mitsubishi', 'nissan', 'peugot', 'plymouth', 'porsche', 'renault',
#        'saab', 'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
#معرفة العدد والانواع

#Know the number and types

df['aspiration'].value_counts()
# Out:
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# subaru           12
# volkswagen       12
# volvo            11
# peugot           11
# dodge             9
# bmw               8
# mercedes-benz     8
# plymouth          7
# audi              6
# saab              6
# porsche           4
# jaguar            3
# chevrolet         3
# alfa-romero       3
# isuzu             2
# renault           2
# mercury           1
# Name: aspiration, dtype: int64

# %%
#التعديل ع الاسماء الاعمدة
    
#Editing the names is deliberate    
    
num=df.describe()

num.columns

df[['symboling', 'normalized-losses', 'make', 'fuel-type', 'width',
       'height', 'curb-weight', 'engine-type', 'num-of-cylinders', 'bore',
       'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
       'highway-mpg', 'price', 'Unnamed: 26', 'Unnamed: 27']]
# Out:
#      symboling  normalized-losses  make  fuel-type  width  height  \
# 0          NaN                  0     3        122   88.6   168.8
# 1          NaN                  1     3        122   88.6   168.8
# 2          NaN                  2     1        122   94.5   171.2
# 3          NaN                  3     2        164   99.8   176.6
# 4          NaN                  4     2        164   99.4   176.6
# ..         ...                ...   ...        ...    ...     ...
# 196        NaN                200    -1         95  109.1   188.8
# 197        NaN                201    -1         95  109.1   188.8
# 198        NaN                202    -1         95  109.1   188.8
# 199        NaN                203    -1         95  109.1   188.8
# 200        NaN                204    -1         95    NaN     NaN
#
#      curb-weight  engine-type  num-of-cylinders   bore  compression-ratio  \
# 0           64.1         48.8            2548.0  130.0               3.47
# 1           64.1         48.8            2548.0  130.0               3.47
# 2           65.5         52.4            2823.0  152.0               2.68
# 3           66.2         54.3            2337.0  109.0               3.19
# 4           66.4         54.3            2824.0  136.0               3.19
# ..           ...          ...               ...    ...                ...
# 196         68.9         55.5            2952.0  141.0               3.78
# 197         68.8         55.5            3049.0  141.0               3.78
# 198         68.9         55.5            3012.0  173.0               3.58
# 199         68.9         55.5            3217.0  145.0               3.01
# 200          NaN          NaN               NaN    NaN                NaN
#
#      horsepower  peak-rpm  city-mpg  highway-mpg  price  Unnamed: 26  \
# 0          2.68       9.0     111.0       5000.0   21.0         27.0
# 1          2.68       9.0     111.0       5000.0   21.0         27.0
# 2          3.47       9.0     154.0       5000.0   19.0         26.0
# 3          3.40      10.0     102.0       5500.0   24.0         30.0
# 4          3.40       8.0     115.0       5500.0   18.0         22.0
# ..          ...       ...       ...          ...    ...          ...
# 196        3.15       9.5     114.0       5400.0   23.0         28.0
# 197        3.15       8.7     160.0       5300.0   19.0         25.0
# 198        2.87       8.8     134.0       5500.0   18.0         23.0
# 199        3.40      23.0     106.0       4800.0   26.0         27.0
# 200         NaN       NaN       NaN          NaN    NaN          NaN
#
#      Unnamed: 27
# 0        13495.0
# 1        16500.0
# 2        16500.0
# 3        13950.0
# 4        17450.0
# ..           ...
# 196      16845.0
# 197      19045.0
# 198      21485.0
# 199      22470.0
# 200          NaN
#
# [201 rows x 18 columns]

# %%
#معرفة سعر السيارات 

#Find out the price of cars 

df.groupby('aspiration')['highway-mpg'].mean()
# Out:
# aspiration
# alfa-romero      5000.000000
# audi             5500.000000
# bmw              5068.750000
# chevrolet        5300.000000
# dodge            5388.888889
# honda            5753.846154
# isuzu            4900.000000
# jaguar           4833.333333
# mazda            5108.823529
# mercedes-benz    4487.500000
# mercury          5000.000000
# mitsubishi       5269.230769
# nissan           5177.777778
# peugot           4668.181818
# plymouth         5357.142857
# porsche          5800.000000
# renault          5117.587940
# saab             5333.333333
# subaru           4775.000000
# toyota           4859.375000
# volkswagen       5154.166667
# volvo            5280.000000
# Name: highway-mpg, dtype: float64

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price', 'Unnamed: 26', 'Unnamed: 27'],
#       dtype='object')

# %%
#عرض نوع مكان المحرك لكل سيارة

#View engine location and Types for each car


df.groupby(['engine-location','engine-type']).mean()
# Out:
#                              symboling  normalized-losses  make  fuel-type  \
# engine-location engine-type
# convertible     48.8               NaN               0.50  3.00     122.00
#                 50.8               NaN              72.00  3.00     142.00
#                 51.6               NaN             128.00  3.00     122.00
#                 53.0               NaN             172.00  2.00     134.00
#                 55.6               NaN             189.00  3.00     122.00
# ...                                ...                ...   ...        ...
# wagon           57.5               NaN             197.00 -1.00      74.00
#                 58.3               NaN              36.00  0.00      78.00
#                 58.7               NaN             100.25 -0.25     114.75
#                 59.1               NaN             154.00  0.00      83.00
#                 59.8               NaN              75.50 -1.00      92.00
#
#                               width  height  curb-weight  num-of-cylinders  \
# engine-location engine-type
# convertible     48.8          88.60   168.8       64.100       2548.000000
#                 50.8          96.60   180.3       70.500       3685.000000
#                 51.6          89.50   168.9       65.000       2800.000000
#                 53.0          98.40   176.2       65.600       2975.000000
#                 55.6          94.50   159.3       64.200       2254.000000
# ...                             ...     ...          ...               ...
# wagon           57.5         104.30   188.8       67.200       3077.666667
#                 58.3          96.50   157.1       63.900       2024.000000
#                 58.7         113.15   196.9       68.875       3473.750000
#                 59.1          95.70   169.7       63.600       2560.000000
#                 59.8         103.30   174.6       64.600       2535.000000
#
#                                    bore  compression-ratio  horsepower  \
# engine-location engine-type
# convertible     48.8         130.000000           3.470000      2.6800
#                 50.8         234.000000           3.460000      3.1000
#                 51.6         194.000000           3.740000      2.9000
#                 53.0         146.000000           3.620000      3.5000
#                 55.6         109.000000           3.190000      3.4000
# ...                                 ...                ...         ...
# wagon           57.5         137.333333           3.726667      3.1500
#                 58.3          92.000000           2.920000      3.4100
#                 58.7         151.750000           3.610000      3.4675
#                 59.1          92.000000           3.050000      3.0300
#                 59.8         122.000000           3.345000      3.4600
#
#                               peak-rpm  city-mpg  highway-mpg      price  \
# engine-location engine-type
# convertible     48.8          9.000000     111.0       5000.0  21.000000
#                 50.8          8.300000     155.0       4750.0  16.000000
#                 51.6          9.500000     207.0       5900.0  17.000000
#                 53.0          9.300000     116.0       4800.0  24.000000
#                 55.6          8.500000      90.0       5500.0  24.000000
# ...                                ...       ...          ...        ...
# wagon           57.5          8.833333     130.0       5300.0  21.333333
#                 58.3          9.200000      76.0       6000.0  30.000000
#                 58.7         17.975000     102.5       4412.5  22.750000
#                 59.1          9.000000      62.0       4800.0  28.333333
#                 59.8          8.500000      88.0       5000.0  24.000000
#
#                              Unnamed: 26   Unnamed: 27
# engine-location engine-type
# convertible     48.8           27.000000  14997.500000
#                 50.8           18.000000  35056.000000
#                 51.6           25.000000  37028.000000
#                 53.0           30.000000  17669.000000
#                 55.6           29.000000  11595.000000
# ...                                  ...           ...
# wagon           57.5           26.000000  16293.333333
#                 58.3           34.000000   7295.000000
#                 58.7           24.750000  17905.750000
#                 59.1           33.666667   7864.666667
#                 59.8           30.000000   8921.000000
#
# [76 rows x 17 columns]

# %%
#عرض الطول والعرض والمقارنة بينهم 

# Show height width and comparison

df[['height', 'width', 'length']].describe()
# Out:
#            height       width
# count  200.000000  200.000000
# mean   174.128000   98.745500
# std     12.309453    6.037353
# min    141.100000   86.600000
# 25%    166.675000   94.500000
# 50%    173.200000   96.950000
# 75%    183.200000  102.400000
# max    208.100000  120.900000

# %% [markdown]
# # small Visualization data

# %%
#عرض المخططات لجميع البيانات

#View charts for all data

df.hist(figsize=(10,10));

# %%
#حجم المحرك الاكثر استخداما

#The most commonly used engine size

df['fuel-system'].hist(figsize=(8,8));

# %%
#عرض المخطط لجميع انوع السيارات

#View the chart for all types of cars

df['aspiration'].value_counts().plot(kind='bar',figsize=(10,10));
